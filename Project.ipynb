# %%
name='Ecem'
i=1
while True:
    input_name = input('Please enter your name: ')
    if input_name==name:
        print('Welcome ', name)
        break
    elif i<3:
        i+=1
    else:
        print('Please try again later')
        break
# Out:
# Please enter your name: Ecm
# Please enter your name: Ecem
# Welcome  Ecem

# %%
courses = ["1:IE", "2:CS", "3:TURK", "4:ENG", "5:ME", "6:MATH"]
coursesTaken = []

print("Please select minimum 3 maximum 5 courses")
print(courses)

i = 0
while i < 5:
    input_course = int(input("Please enter the number infront of the course name:"))
    if(input_course == 1):
        coursesTaken.append(courses[0])
        print("\n{} successfully added \n".format(courses[0]))
        print(coursesTaken)
    
    if(input_course == 2):
        coursesTaken.append(courses[1])
        print("\n{} successfully added \n".format(courses[0]))
        print(coursesTaken)

    if (input_course == 3):
        coursesTaken.append(courses[2])
        print("\n{} successfully added \n".format(courses[0]))
        print(coursesTaken)

    if (input_course == 4):
        coursesTaken.append(courses[3])
        print("\n{} successfully added \n".format(courses[0]))
        print(coursesTaken)

    if (input_course == 5):
        coursesTaken.append(courses[4])
        print("\n{} successfully added \n".format(courses[0]))
        print(coursesTaken)

    if (input_course == 6):
        coursesTaken.append(courses[5])
        print("\n{} successfully added \n".format(courses[0]))
        print(coursesTaken)
    
    else:
        print('Enter a valid number')

    i += 1
    print("You have {} courses".format(len(coursesTaken)))
    if i < 3:
        print("You must have chosen 3 courses")
    if  i >= 3 and \
        i< 5:
        print("You can take more courses up to 5")
    if i == 5:
        print("Maximum number of courses are taken")
        coursesTaken.sort()
        
        choice = int(input("Choose one of the courses to enter your grades:"))

print("Please enter your grades:")

while True:
    try:
        midterm = int(input('midterm: '))
    except ValueError:
        print("Enter a number")
        exit(-1)
    if 0 < midterm <=100:
        break
    else:
        print("Enter a number between 1-100")

while True:
    try:
        project = int(input('Project: '))
    except ValueError:
        print("Enter a number")
        exit(-1)
    if 0 < project <=100:
        break
    else:
        print("Enter a number between 1-100")

while True:
    try:
        final = int(input('Final: '))
    except ValueError:
        print("Enter a number")
        exit(-1)
    if 0 < final <=100:
        break
    else:
        print("Enter a number between 1-100")

notes={'midterm':midterm, 'project': project, 'final':final}

total = midterm * 0.3 + final * 0.5 + project * 0.2

if 90 < total:
    letterGrade = "AA"
elif 70 < total < 90:
    letterGrade = "BB"
elif 50 < total < 70:
    letterGrade = "CC"
elif 30 < total < 50:
    letterGrade = "DD"
elif total< 30:
    letterGrade = "FF"

print("The result: ({}) {}".format(letterGrade, round(total, 2)))
if letterGrade == 'FF':
    print("Failed!")
else:
    print("Passed!")
# Out:
# Please select minimum 3 maximum 5 courses
# ['1:IE', '2:CS', '3:TURK', '4:ENG', '5:ME', '6:MATH']
# Please enter the number infront of the course name:44
# Enter a valid number
# You have 0 courses
# You must have chosen 3 courses
# Please enter the number infront of the course name:5
#
# => 1:IE successfully added
#
# ['5:ME']
# Enter a valid number
# You have 1 courses
# You must have chosen 3 courses
# Please enter the number infront of the course name:6
#
# => 1:IE successfully added
#
# ['5:ME', '6:MATH']
# You have 2 courses
# You can take more courses up to 5
# Please enter the number infront of the course name:7
# Enter a valid number
# You have 2 courses
# You can take more courses up to 5
# Please enter the number infront of the course name:2
#
# => 1:IE successfully added
#
# ['5:ME', '6:MATH', '2:CS']
# Enter a valid number
# You have 3 courses
# Maximum number of courses are taken
# Choose one of the courses to enter your grades:1
# Please enter your grades:
# ...

# %%
notes.keys()
# Out:
# dict_keys(['midterm', 'project', 'final'])
